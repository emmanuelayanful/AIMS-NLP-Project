# %%
import os
import json
import re
import pandas as pd
from collections import defaultdict

def extract_size(filename):
    """Extracts training size like 1000, 16000 from filename"""
    match = re.search(r'_(\d+)\.(json|txt)$', filename)
    return match.group(1) if match else ""

# Dictionary to hold results
all_results = {}

# Root results directory
results_dir = "results/"  # Change if needed

for lang_pair in os.listdir(results_dir):
    lang_path = os.path.join(results_dir, lang_pair)
    if not os.path.isdir(lang_path):
        continue

    # Temporary group: run_type → values
    grouped = defaultdict(dict)

    for filename in os.listdir(lang_path):
        filepath = os.path.join(lang_path, filename)
        if not (filename.endswith(".json") or filename.endswith(".txt")):
            continue

        # Determine run type and size
        size = extract_size(filename)
        if "africomet_base" in filename:
            run_type = f"africomet + baseline {size}" if size else "africomet + baseline"
        elif "africomet" in filename:
            run_type = f"africomet {size}" if size else "africomet"
        elif "random" in filename:
            run_type = f"random {size}" if size else "random"
        elif "baseline" in filename:
            run_type = "baseline"
        else:
            continue

        # === Handle JSON file ===
        if filename.endswith(".json"):
            with open(filepath, "r") as f:
                scores = json.load(f)
                grouped[run_type]["predict_bleu"] = scores.get("predict_bleu")
                grouped[run_type]["eval_bleu"] = scores.get("eval_bleu")
                grouped[run_type]["predict_chrf"] = scores.get("predict_chrf")
                grouped[run_type]["eval_chrf"] = scores.get("eval_chrf")

        # === Handle AfriCOMET score in .txt ===
        elif filename.endswith(".txt"):
            with open(filepath, "r") as f:
                lines = f.readlines()
                if lines:
                    last_line = lines[-1].strip()
                    if "score:" in last_line:
                        try:
                            score_str = last_line.split("score:")[-1].strip()
                            grouped[run_type]["africomet"] = float(score_str) * 100
                        except ValueError:
                            grouped[run_type]["africomet"] = None

    # Finalize list of rows for this language pair
    lang_results = []
    for run_type, metrics in grouped.items():
        row = {"run type": run_type}
        row.update(metrics)
        lang_results.append(row)

    all_results[lang_pair] = lang_results

# === Save to Excel ===
with pd.ExcelWriter("model_results.xlsx") as writer:
    for lang_pair, records in all_results.items():
        df = pd.DataFrame(records)
        df = df.sort_values(by="run type")
        df.to_excel(writer, sheet_name=lang_pair[:31], index=False, float_format="%.4f")

# %%
all_results
# Out:
# {'en-zu': [{'run type': 'africomet 4000',
#    'predict_bleu': 3.0383,
#    'eval_bleu': 3.4902,
#    'predict_chrf': 26.7978,
#    'eval_chrf': 27.4526,
#    'africomet': 34.44},
#   {'run type': 'random 1000',
#    'africomet': 23.27,
#    'predict_bleu': 1.7561,
#    'eval_bleu': 1.8897,
#    'predict_chrf': 19.5618,
#    'eval_chrf': 20.7152},
#   {'run type': 'africomet 16000',
#    'predict_bleu': 6.614,
#    'eval_bleu': 6.9138,
#    'predict_chrf': 39.8583,
#    'eval_chrf': 40.2587,
#    'africomet': 57.410000000000004},
#   {'run type': 'random 2000',
#    'predict_bleu': 2.1395,
#    'eval_bleu': 2.8959,
#    'predict_chrf': 21.9348,
#    'eval_chrf': 23.4902,
#    'africomet': 27.139999999999997},
#   {'run type': 'random 16000',
#    'predict_bleu': 5.4113,
#    'eval_bleu': 6.3626,
#    'predict_chrf': 36.3241,
#    'eval_chrf': 37.5336,
#    'africomet': 50.519999999999996},
#   {'run type': 'africomet 2000',
#    'africomet': 31.03,
#    'predict_bleu': 2.9101,
#    'eval_bleu': 3.3998,
#    'predict_chrf': 24.5707,
#    'eval_chrf': 25.2194},
#   {'run type': 'africomet + baseline 1000',
#    'africomet': 60.309999999999995,
#    'predict_bleu': 7.1894,
#    'eval_bleu': 7.5352,
#    'predict_chrf': 41.8942,
#    'eval_chrf': 42.1375},
#   {'run type': 'random 32000',
#    'predict_bleu': 7.3146,
#    'eval_bleu': 7.8131,
#    'predict_chrf': 41.4494,
#    'eval_chrf': 42.0905,
#    'africomet': 59.43000000000001},
#   {'run type': 'africomet 32000',
#    'africomet': 66.42,
#    'predict_bleu': 8.6827,
#    'eval_bleu': 9.0027,
#    'predict_chrf': 44.8391,
#    'eval_chrf': 45.3705},
#   {'run type': 'random 8000',
#    'predict_bleu': 4.1752,
#    'eval_bleu': 4.7988,
#    'predict_chrf': 31.8262,
#    'eval_chrf': 33.0758,
#    'africomet': 41.82},
#   {'run type': 'africomet 8000',
#    'africomet': 46.18,
#    'predict_bleu': 4.6125,
#    'eval_bleu': 5.15,
#    'predict_chrf': 34.065,
#    'eval_chrf': 34.9965},
#   {'run type': 'africomet + baseline 4000',
#    'predict_bleu': 7.8014,
#    'eval_bleu': 8.0342,
#    'predict_chrf': 43.4225,
#    'eval_chrf': 43.2791,
#    'africomet': 62.739999999999995},
#   {'run type': 'africomet 1000',
#    'africomet': 23.22,
#    'predict_bleu': 1.7483,
#    'eval_bleu': 2.2582,
#    'predict_chrf': 19.7319,
#    'eval_chrf': 20.7278},
#   {'run type': 'africomet + baseline 8000',
#    'predict_bleu': 8.9661,
#    'eval_bleu': 8.8182,
#    'predict_chrf': 44.7923,
#    'eval_chrf': 45.1535,
#    'africomet': 64.55},
#   {'run type': 'africomet + baseline 32000',
#    'predict_bleu': 11.0822,
#    'eval_bleu': 11.0151,
#    'predict_chrf': 49.0115,
#    'eval_chrf': 49.4009,
#    'africomet': 71.43},
#   {'run type': 'random 4000',
#    'predict_bleu': 3.0754,
#    'eval_bleu': 3.522,
#    'predict_chrf': 26.7476,
#    'eval_chrf': 26.9925,
#    'africomet': 33.14},
#   {'run type': 'africomet + baseline 16000',
#    'africomet': 68.38,
#    'predict_bleu': 9.8858,
#    'eval_bleu': 9.9913,
#    'predict_chrf': 47.0168,
#    'eval_chrf': 46.8739},
#   {'run type': 'baseline',
#    'predict_bleu': 7.4115,
#    'eval_bleu': 7.5246,
#    'predict_chrf': 42.1132,
#    'eval_chrf': 42.4029,
#    'africomet': 60.099999999999994},
#   {'run type': 'africomet + baseline 2000',
#    'predict_bleu': 7.5681,
#    'eval_bleu': 7.6748,
#    'predict_chrf': 42.4477,
#    'eval_chrf': 42.5391,
#    'africomet': 61.050000000000004}],
#  'en-yo': [{'run type': 'random 16000',
#    'africomet': 29.330000000000002,
#    'predict_bleu': 2.259,
#    'eval_bleu': 2.6018,
#    'predict_chrf': 17.0989,
#    'eval_chrf': 17.8236},
#   {'run type': 'africomet 8000',
#    'africomet': 29.98,
#    'predict_bleu': 2.3066,
#    'eval_bleu': 2.7618,
#    'predict_chrf': 17.146,
#    'eval_chrf': 18.1342},
#   {'run type': 'africomet 4000',
#    'africomet': 24.87,
#    'predict_bleu': 1.9582,
#    'eval_bleu': 2.251,
#    'predict_chrf': 15.4081,
#    'eval_chrf': 15.9686},
#   {'run type': 'random 32000',
#    'africomet': 32.31,
#    'predict_bleu': 2.4363,
#    'eval_bleu': 2.9492,
#    'predict_chrf': 18.0688,
#    'eval_chrf': 18.9326},
#   {'run type': 'random 2000',
#    'africomet': 19.28,
#    'predict_bleu': 1.455,
#    'eval_bleu': 1.7998,
#    'predict_chrf': 13.2411,
#    'eval_chrf': 14.0449},
#   {'run type': 'africomet 2000',
#    'predict_bleu': 1.825,
#    'eval_bleu': 2.0459,
#    'predict_chrf': 13.6629,
#    'eval_chrf': 14.4088,
#    'africomet': 20.810000000000002},
#   {'run type': 'africomet + baseline 4000',
#    'predict_bleu': 5.8362,
#    'eval_bleu': 5.8126,
#    'predict_chrf': 25.635,
#    'eval_chrf': 26.1944,
#    'africomet': 61.83},
#   {'run type': 'random 4000',
#    'predict_bleu': 1.851,
#    'eval_bleu': 2.1924,
#    'predict_chrf': 14.551,
#    'eval_chrf': 15.2399,
#    'africomet': 21.94},
#   {'run type': 'africomet 1000',
#    'predict_bleu': 1.3265,
#    'eval_bleu': 1.4961,
#    'predict_chrf': 11.1082,
#    'eval_chrf': 11.3544,
#    'africomet': 15.740000000000002},
#   {'run type': 'random 8000',
#    'africomet': 25.61,
#    'predict_bleu': 2.1956,
#    'eval_bleu': 2.4181,
#    'predict_chrf': 16.0142,
#    'eval_chrf': 16.6916},
#   {'run type': 'africomet + baseline 1000',
#    'africomet': 63.85999999999999,
#    'predict_bleu': 6.0861,
#    'eval_bleu': 5.7919,
#    'predict_chrf': 26.0381,
#    'eval_chrf': 26.348},
#   {'run type': 'africomet + baseline 2000',
#    'predict_bleu': 6.2332,
#    'eval_bleu': 5.94,
#    'predict_chrf': 26.3865,
#    'eval_chrf': 26.5665,
#    'africomet': 64.4},
#   {'run type': 'africomet 32000',
#    'predict_bleu': 2.5804,
#    'eval_bleu': 3.1835,
#    'predict_chrf': 19.4017,
#    'eval_chrf': 20.3393,
#    'africomet': 37.419999999999995},
#   {'run type': 'baseline',
#    'africomet': 64.47,
#    'predict_bleu': 5.801,
#    'eval_bleu': 5.7155,
#    'predict_chrf': 25.8441,
#    'eval_chrf': 26.1312},
#   {'run type': 'africomet + baseline 32000',
#    'predict_bleu': 5.0855,
#    'eval_bleu': 4.954,
#    'predict_chrf': 24.6531,
#    'eval_chrf': 24.7178,
#    'africomet': 53.83},
#   {'run type': 'africomet + baseline 8000',
#    'africomet': 59.93000000000001,
#    'predict_bleu': 5.7618,
#    'eval_bleu': 5.7072,
#    'predict_chrf': 25.6465,
#    'eval_chrf': 26.059},
#   {'run type': 'random 1000',
#    'africomet': 17.22,
#    'predict_bleu': 1.4506,
#    'eval_bleu': 1.7677,
#    'predict_chrf': 13.131,
#    'eval_chrf': 13.7565},
#   {'run type': 'africomet + baseline 16000',
#    'africomet': 57.82000000000001,
#    'predict_bleu': 5.5635,
#    'eval_bleu': 5.7478,
#    'predict_chrf': 25.4545,
#    'eval_chrf': 25.8004},
#   {'run type': 'africomet 16000',
#    'africomet': 33.54,
#    'predict_bleu': 2.3505,
#    'eval_bleu': 2.9705,
#    'predict_chrf': 18.214,
#    'eval_chrf': 19.2155}],
#  'en-ha': [{'run type': 'baseline',
#    'africomet': 51.73,
#    'predict_bleu': 8.722,
#    'eval_bleu': 8.5945,
#    'predict_chrf': 35.4816,
#    'eval_chrf': 35.7502},
#   {'run type': 'random 8000',
#    'africomet': 48.38,
#    'predict_bleu': 11.654,
#    'eval_bleu': 11.92,
#    'predict_chrf': 35.2402,
#    'eval_chrf': 36.3399},
#   {'run type': 'africomet 32000',
#    'predict_bleu': 18.1024,
#    'eval_bleu': 18.8507,
#    'predict_chrf': 45.3327,
#    'eval_chrf': 46.48,
#    'africomet': 67.85},
#   {'run type': 'random 4000',
#    'africomet': 35.86,
#    'predict_bleu': 8.1237,
#    'eval_bleu': 8.3448,
#    'predict_chrf': 28.2072,
#    'eval_chrf': 29.8212},
#   {'run type': 'africomet + baseline 4000',
#    'predict_bleu': 12.5746,
#    'eval_bleu': 12.8778,
#    'predict_chrf': 39.77,
#    'eval_chrf': 40.5896,
#    'africomet': 58.81999999999999},
#   {'run type': 'random 2000',
#    'predict_bleu': 6.1058,
#    'eval_bleu': 6.3225,
#    'predict_chrf': 23.0044,
#    'eval_chrf': 23.6597,
#    'africomet': 27.63},
#   {'run type': 'africomet 4000',
#    'africomet': 41.89,
#    'predict_bleu': 9.8337,
#    'eval_bleu': 9.8043,
#    'predict_chrf': 31.8099,
#    'eval_chrf': 33.0084},
#   {'run type': 'africomet 8000',
#    'africomet': 53.5,
#    'predict_bleu': 12.8287,
#    'eval_bleu': 13.8321,
#    'predict_chrf': 37.6936,
#    'eval_chrf': 39.553},
#   {'run type': 'africomet + baseline 8000',
#    'africomet': 62.33,
#    'predict_bleu': 13.9095,
#    'eval_bleu': 14.7245,
#    'predict_chrf': 41.4214,
#    'eval_chrf': 42.3338},
#   {'run type': 'africomet + baseline 32000',
#    'predict_bleu': 18.6285,
#    'eval_bleu': 19.2746,
#    'predict_chrf': 46.4347,
#    'eval_chrf': 47.2898,
#    'africomet': 70.05},
#   {'run type': 'africomet 2000',
#    'africomet': 33.6,
#    'predict_bleu': 7.2913,
#    'eval_bleu': 7.6605,
#    'predict_chrf': 27.2458,
#    'eval_chrf': 28.2344},
#   {'run type': 'africomet + baseline 16000',
#    'predict_bleu': 16.8078,
#    'eval_bleu': 17.7392,
#    'predict_chrf': 44.0274,
#    'eval_chrf': 45.5728,
#    'africomet': 66.3},
#   {'run type': 'random 1000',
#    'predict_bleu': 5.2633,
#    'eval_bleu': 5.3175,
#    'predict_chrf': 22.8082,
#    'eval_chrf': 23.6113,
#    'africomet': 24.7},
#   {'run type': 'africomet 16000',
#    'predict_bleu': 15.4818,
#    'eval_bleu': 16.3561,
#    'predict_chrf': 41.8843,
#    'eval_chrf': 43.2219,
#    'africomet': 61.51},
#   {'run type': 'africomet + baseline 2000',
#    'africomet': 54.43,
#    'predict_bleu': 10.4317,
#    'eval_bleu': 11.4362,
#    'predict_chrf': 36.5733,
#    'eval_chrf': 38.6543},
#   {'run type': 'random 32000',
#    'africomet': 63.59,
#    'predict_bleu': 16.6199,
#    'eval_bleu': 16.8994,
#    'predict_chrf': 43.4762,
#    'eval_chrf': 43.896},
#   {'run type': 'random 16000',
#    'africomet': 56.16,
#    'predict_bleu': 13.999,
#    'eval_bleu': 14.4263,
#    'predict_chrf': 38.8994,
#    'eval_chrf': 39.8721},
#   {'run type': 'africomet + baseline 1000',
#    'africomet': 52.959999999999994,
#    'predict_bleu': 9.9554,
#    'eval_bleu': 10.4591,
#    'predict_chrf': 36.1249,
#    'eval_chrf': 36.6678},
#   {'run type': 'africomet 1000',
#    'predict_bleu': 5.7504,
#    'eval_bleu': 5.4181,
#    'predict_chrf': 22.7686,
#    'eval_chrf': 23.2442,
#    'africomet': 25.34}],
#  'en-ig': [{'run type': 'africomet + baseline 2000',
#    'africomet': 67.14,
#    'predict_bleu': 12.3662,
#    'eval_bleu': 12.4136,
#    'predict_chrf': 37.8633,
#    'eval_chrf': 37.8353},
#   {'run type': 'africomet 8000',
#    'predict_bleu': 10.3958,
#    'eval_bleu': 10.4539,
#    'predict_chrf': 32.3445,
#    'eval_chrf': 33.0929,
#    'africomet': 56.92},
#   {'run type': 'random 8000',
#    'africomet': 50.62,
#    'predict_bleu': 9.0445,
#    'eval_bleu': 9.2135,
#    'predict_chrf': 30.3721,
#    'eval_chrf': 30.8558},
#   {'run type': 'africomet 1000',
#    'predict_bleu': 5.6731,
#    'eval_bleu': 5.2212,
#    'predict_chrf': 22.2614,
#    'eval_chrf': 22.5921,
#    'africomet': 34.73},
#   {'run type': 'random 4000',
#    'africomet': 43.34,
#    'predict_bleu': 7.8122,
#    'eval_bleu': 7.7275,
#    'predict_chrf': 26.8317,
#    'eval_chrf': 28.1499},
#   {'run type': 'random 2000',
#    'predict_bleu': 6.2147,
#    'eval_bleu': 6.0674,
#    'predict_chrf': 23.6068,
#    'eval_chrf': 24.1443,
#    'africomet': 35.449999999999996},
#   {'run type': 'baseline',
#    'africomet': 66.23,
#    'predict_bleu': 11.1604,
#    'eval_bleu': 10.9085,
#    'predict_chrf': 36.6716,
#    'eval_chrf': 36.6315},
#   {'run type': 'africomet + baseline 4000',
#    'predict_bleu': 12.3855,
#    'eval_bleu': 12.368,
#    'predict_chrf': 37.9643,
#    'eval_chrf': 38.0412,
#    'africomet': 67.75},
#   {'run type': 'africomet 2000',
#    'predict_bleu': 6.5941,
#    'eval_bleu': 6.5663,
#    'predict_chrf': 24.8874,
#    'eval_chrf': 25.5598,
#    'africomet': 40.5},
#   {'run type': 'africomet + baseline 8000',
#    'africomet': 68.37,
#    'predict_bleu': 13.3298,
#    'eval_bleu': 13.0979,
#    'predict_chrf': 38.9347,
#    'eval_chrf': 39.1157},
#   {'run type': 'random 1000',
#    'predict_bleu': 4.7164,
#    'eval_bleu': 4.7485,
#    'predict_chrf': 20.6191,
#    'eval_chrf': 21.4809,
#    'africomet': 30.080000000000002},
#   {'run type': 'random 16000',
#    'predict_bleu': 10.8804,
#    'eval_bleu': 10.9436,
#    'predict_chrf': 33.9117,
#    'eval_chrf': 34.5133,
#    'africomet': 57.78},
#   {'run type': 'africomet 32000',
#    'predict_bleu': 13.5518,
#    'eval_bleu': 12.748,
#    'predict_chrf': 38.0181,
#    'eval_chrf': 38.2061,
#    'africomet': 66.85},
#   {'run type': 'africomet + baseline 16000',
#    'predict_bleu': 14.1809,
#    'eval_bleu': 13.4527,
#    'predict_chrf': 40.1988,
#    'eval_chrf': 39.9157,
#    'africomet': 70.08},
#   {'run type': 'africomet + baseline 1000',
#    'africomet': 66.67999999999999,
#    'predict_bleu': 11.6901,
#    'eval_bleu': 11.995,
#    'predict_chrf': 37.3213,
#    'eval_chrf': 37.6263},
#   {'run type': 'random 32000',
#    'africomet': 62.23,
#    'predict_bleu': 12.0559,
#    'eval_bleu': 11.9203,
#    'predict_chrf': 36.1907,
#    'eval_chrf': 36.9465},
#   {'run type': 'africomet 16000',
#    'africomet': 63.63999999999999,
#    'predict_bleu': 11.6773,
#    'eval_bleu': 11.7413,
#    'predict_chrf': 35.6025,
#    'eval_chrf': 36.0724},
#   {'run type': 'africomet 4000',
#    'africomet': 48.3,
#    'predict_bleu': 8.2924,
#    'eval_bleu': 8.4748,
#    'predict_chrf': 28.002,
#    'eval_chrf': 29.1282},
#   {'run type': 'africomet + baseline 32000',
#    'predict_bleu': 14.9561,
#    'eval_bleu': 14.1235,
#    'predict_chrf': 40.9978,
#    'eval_chrf': 40.4925,
#    'africomet': 71.46000000000001}],
#  'en-sw': [{'run type': 'random 4000',
#    'predict_bleu': 1.7771,
#    'eval_bleu': 1.9326,
#    'predict_chrf': 14.6112,
#    'eval_chrf': 14.7152,
#    'africomet': 24.69},
#   {'run type': 'africomet + baseline 4000',
#    'predict_bleu': 6.1047,
#    'eval_bleu': 6.9937,
#    'predict_chrf': 28.1989,
#    'eval_chrf': 29.1895,
#    'africomet': 57.010000000000005},
#   {'run type': 'baseline',
#    'predict_bleu': 5.2412,
#    'eval_bleu': 5.6147,
#    'predict_chrf': 26.0251,
#    'eval_chrf': 26.7379,
#    'africomet': 51.28},
#   {'run type': 'africomet 4000',
#    'africomet': 28.34,
#    'predict_bleu': 1.8731,
#    'eval_bleu': 2.2776,
#    'predict_chrf': 15.2782,
#    'eval_chrf': 16.2293},
#   {'run type': 'africomet 8000',
#    'africomet': 44.62,
#    'predict_bleu': 3.6363,
#    'eval_bleu': 3.9761,
#    'predict_chrf': 21.6189,
#    'eval_chrf': 22.1985},
#   {'run type': 'africomet 16000',
#    'predict_bleu': 4.74,
#    'eval_bleu': 5.4435,
#    'predict_chrf': 23.8555,
#    'eval_chrf': 24.936,
#    'africomet': 52.21},
#   {'run type': 'random 1000',
#    'africomet': 13.29,
#    'predict_bleu': 1.1604,
#    'eval_bleu': 1.4119,
#    'predict_chrf': 10.2422,
#    'eval_chrf': 10.7518},
#   {'run type': 'random 32000',
#    'africomet': 50.19,
#    'predict_bleu': 4.4524,
#    'eval_bleu': 4.8737,
#    'predict_chrf': 22.755,
#    'eval_chrf': 23.2303},
#   {'run type': 'random 16000',
#    'africomet': 44.529999999999994,
#    'predict_bleu': 3.4293,
#    'eval_bleu': 3.9651,
#    'predict_chrf': 20.671,
#    'eval_chrf': 21.0},
#   {'run type': 'africomet 2000',
#    'africomet': 22.650000000000002,
#    'predict_bleu': 1.1815,
#    'eval_bleu': 1.4197,
#    'predict_chrf': 13.0894,
#    'eval_chrf': 13.8609},
#   {'run type': 'africomet + baseline 1000',
#    'africomet': 50.81,
#    'predict_bleu': 5.5389,
#    'eval_bleu': 6.3949,
#    'predict_chrf': 26.2197,
#    'eval_chrf': 27.559},
#   {'run type': 'africomet 32000',
#    'africomet': 60.47,
#    'predict_bleu': 5.6471,
#    'eval_bleu': 6.376,
#    'predict_chrf': 27.0208,
#    'eval_chrf': 27.5963},
#   {'run type': 'random 2000',
#    'africomet': 14.44,
#    'predict_bleu': 0.9229,
#    'eval_bleu': 1.265,
#    'predict_chrf': 9.4858,
#    'eval_chrf': 10.2339},
#   {'run type': 'africomet + baseline 8000',
#    'africomet': 60.309999999999995,
#    'predict_bleu': 6.5348,
#    'eval_bleu': 7.3907,
#    'predict_chrf': 29.4715,
#    'eval_chrf': 30.2075},
#   {'run type': 'africomet + baseline 2000',
#    'predict_bleu': 5.4915,
#    'eval_bleu': 6.4759,
#    'predict_chrf': 26.4863,
#    'eval_chrf': 27.8224,
#    'africomet': 52.190000000000005},
#   {'run type': 'africomet + baseline 16000',
#    'predict_bleu': 7.0655,
#    'eval_bleu': 7.5174,
#    'predict_chrf': 30.178,
#    'eval_chrf': 30.9813,
#    'africomet': 62.49},
#   {'run type': 'africomet + baseline 32000',
#    'africomet': 65.57,
#    'predict_bleu': 7.3796,
#    'eval_bleu': 8.2785,
#    'predict_chrf': 31.5519,
#    'eval_chrf': 32.44},
#   {'run type': 'africomet 1000',
#    'predict_bleu': 0.9036,
#    'eval_bleu': 1.0128,
#    'predict_chrf': 7.9496,
#    'eval_chrf': 8.2737,
#    'africomet': 13.530000000000001},
#   {'run type': 'random 8000',
#    'africomet': 31.71,
#    'predict_bleu': 1.9952,
#    'eval_bleu': 2.4604,
#    'predict_chrf': 16.3671,
#    'eval_chrf': 17.3653}],
#  'fr-sw': [{'run type': 'africomet 16000',
#    'africomet': 46.400000000000006,
#    'predict_bleu': 4.895,
#    'eval_bleu': 5.3507,
#    'predict_chrf': 24.6959,
#    'eval_chrf': 24.9265},
#   {'run type': 'africomet 32000',
#    'africomet': 51.910000000000004,
#    'predict_bleu': 5.7115,
#    'eval_bleu': 5.9926,
#    'predict_chrf': 26.8959,
#    'eval_chrf': 26.5609},
#   {'run type': 'random 32000',
#    'predict_bleu': 4.9884,
#    'eval_bleu': 5.3059,
#    'predict_chrf': 25.407,
#    'eval_chrf': 25.6039,
#    'africomet': 49.49},
#   {'run type': 'random 8000',
#    'predict_bleu': 2.8004,
#    'eval_bleu': 3.1506,
#    'predict_chrf': 18.4441,
#    'eval_chrf': 18.2419,
#    'africomet': 32.59},
#   {'run type': 'africomet + baseline 4000',
#    'africomet': 50.9,
#    'predict_bleu': 4.8382,
#    'eval_bleu': 5.5665,
#    'predict_chrf': 26.1625,
#    'eval_chrf': 26.3202},
#   {'run type': 'random 1000',
#    'predict_bleu': 1.1423,
#    'eval_bleu': 1.1021,
#    'predict_chrf': 9.1581,
#    'eval_chrf': 9.0797,
#    'africomet': 11.86},
#   {'run type': 'africomet + baseline 8000',
#    'africomet': 52.980000000000004,
#    'predict_bleu': 5.9716,
#    'eval_bleu': 6.2896,
#    'predict_chrf': 27.7193,
#    'eval_chrf': 27.9127},
#   {'run type': 'africomet 1000',
#    'africomet': 12.35,
#    'predict_bleu': 1.3099,
#    'eval_bleu': 1.4049,
#    'predict_chrf': 10.453,
#    'eval_chrf': 10.5715},
#   {'run type': 'africomet 4000',
#    'predict_bleu': 2.1997,
#    'eval_bleu': 2.9505,
#    'predict_chrf': 15.8205,
#    'eval_chrf': 16.2432,
#    'africomet': 25.130000000000003},
#   {'run type': 'africomet + baseline 2000',
#    'africomet': 49.86,
#    'predict_bleu': 4.191,
#    'eval_bleu': 4.6787,
#    'predict_chrf': 25.3901,
#    'eval_chrf': 25.3833},
#   {'run type': 'random 2000',
#    'predict_bleu': 1.5605,
#    'eval_bleu': 1.7702,
#    'predict_chrf': 11.9885,
#    'eval_chrf': 11.9626,
#    'africomet': 15.7},
#   {'run type': 'random 16000',
#    'predict_bleu': 4.3905,
#    'eval_bleu': 4.8345,
#    'predict_chrf': 23.6361,
#    'eval_chrf': 24.3099,
#    'africomet': 46.22},
#   {'run type': 'africomet + baseline 1000',
#    'predict_bleu': 4.0462,
#    'eval_bleu': 4.7269,
#    'predict_chrf': 24.1724,
#    'eval_chrf': 24.6833,
#    'africomet': 48.16},
#   {'run type': 'africomet + baseline 32000',
#    'africomet': 54.96,
#    'predict_bleu': 6.6518,
#    'eval_bleu': 7.0704,
#    'predict_chrf': 29.4468,
#    'eval_chrf': 30.115},
#   {'run type': 'africomet + baseline 16000',
#    'africomet': 54.83,
#    'predict_bleu': 6.2488,
#    'eval_bleu': 6.6211,
#    'predict_chrf': 28.9758,
#    'eval_chrf': 28.4805},
#   {'run type': 'africomet 8000',
#    'predict_bleu': 4.262,
#    'eval_bleu': 4.724,
#    'predict_chrf': 23.3838,
#    'eval_chrf': 23.7726,
#    'africomet': 42.11},
#   {'run type': 'baseline',
#    'africomet': 51.82,
#    'predict_bleu': 3.5708,
#    'eval_bleu': 3.9174,
#    'predict_chrf': 24.4753,
#    'eval_chrf': 24.4352},
#   {'run type': 'random 4000',
#    'africomet': 17.36,
#    'predict_bleu': 1.8279,
#    'eval_bleu': 2.2103,
#    'predict_chrf': 12.2704,
#    'eval_chrf': 12.4218},
#   {'run type': 'africomet 2000',
#    'africomet': 18.66,
#    'predict_bleu': 1.7018,
#    'eval_bleu': 1.9926,
#    'predict_chrf': 13.1558,
#    'eval_chrf': 13.333}]}

# %%
import os
import matplotlib.pyplot as plt

FONTSIZE = 18
params = {
         'axes.labelsize': FONTSIZE,
         'axes.titlesize': FONTSIZE,
         'xtick.labelsize':FONTSIZE,
         'legend.fontsize':FONTSIZE,
         'ytick.labelsize':FONTSIZE}

plt.rcParams.update(params)

# Metric to plot
metric = "africomet" # change with eval_bleu, predict_bleu, eval_chrf, predict_chrf, africomet

# Output folder
os.makedirs("plots", exist_ok=True)

for lang_pair, results in all_results.items():
    series = {"random": {}, "africomet": {}, "africomet + baseline": {}, "baseline": {}}

    for entry in results:
        run_type = entry["run type"]
        value = entry.get(metric)

        if run_type == "baseline":
            series["baseline"]["baseline"] = value
        else:
            for key in ["random", "africomet + baseline", "africomet"]:
                if key in run_type:
                    size = run_type.replace(key, "").strip()
                    try:
                        size = int(size)
                        series[key][size] = value
                    except ValueError:
                        continue

    for key in ["random", "africomet + baseline", "africomet"]:
        series[key] = dict(sorted(series[key].items()))

    # Check if there's anything to plot
    something_to_plot = any(len(data) > 0 for key, data in series.items() if key != "baseline")
    has_baseline = "baseline" in series and "baseline" in series["baseline"]

    if not something_to_plot and not has_baseline:
        print(f"⚠️ Skipping {lang_pair} — no data for {metric}")
        continue

    # === Plot ===
    fig, ax = plt.subplots(figsize=(8, 5), dpi=300)

    for label, data in series.items():
        if label == "baseline" and has_baseline:
            ax.axhline(y=data["baseline"], linestyle='--', color='gray', label="baseline")
        elif len(data) > 0:
            ax.plot(list(data.keys()), list(data.values()), marker='o', label=label)

    #ax.set_title(f"{lang_pair.upper()} – {metric}", fontsize=14)
    ax.set_xlabel("Training Size")
    ax.set_ylabel(metric)
    ax.grid(True, linestyle="--", alpha=0.6)
    ax.legend()
    plt.tight_layout()

    # Save the figure
    save_path = os.path.join("plots", f"{lang_pair}_{metric}.pdf")
    fig.savefig(save_path, format="pdf", dpi=300)
    plt.close(fig)  # Free memory

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

FONTSIZE = 16
plt.rcParams.update({
    'font.size': FONTSIZE,
    'axes.labelsize': FONTSIZE,
    'axes.titlesize': FONTSIZE,
    'xtick.labelsize': FONTSIZE,
    'ytick.labelsize': FONTSIZE,
    'legend.fontsize': FONTSIZE,
})

os.makedirs("plots", exist_ok=True)

metrics = ["predict_bleu", "predict_chrf", "africomet"]
sizes = [1000, 2000, 4000, 8000, 16000, 32000]
groups = {
    "africomet + baseline": "africomet + baseline",
    "africomet": "africomet",
    "random": "random"
}

for lang_pair, results in all_results.items():
    # Find baseline
    baseline_entry = next((r for r in results if r["run type"] == "baseline"), None)
    if not baseline_entry:
        print(f"⚠️ No baseline for {lang_pair}, skipping")
        continue

    baseline_scores = {m: baseline_entry.get(m, 0) for m in metrics}

    for group_name, pattern in groups.items():
        # Initialize
        delta_values = {m: [] for m in metrics}
        available_sizes = []

        for size in sizes:
            # Build run type string
            run_type = f"{pattern} {size}"
            entry = next((r for r in results if r["run type"] == run_type), None)
            if not entry:
                continue  # skip missing runs

            available_sizes.append(size)
            for m in metrics:
                val = entry.get(m)
                baseline = baseline_scores.get(m)
                delta = val - baseline if val is not None and baseline is not None else None
                delta_values[m].append(delta)

        if not available_sizes:
            continue  # nothing to plot for this group

        # Plotting
        x = np.arange(len(available_sizes))
        width = 0.25
        offsets = [-width, 0, width]

        fig, ax = plt.subplots(figsize=(10, 6), dpi=300)
        colors = ["tab:blue", "tab:orange", "tab:green"]

        for i, m in enumerate(metrics):
            ax.bar(x + offsets[i], delta_values[m], width, label=m, color=colors[i])

        ax.axhline(0, linestyle="--", color="black", linewidth=1)
        ax.set_xticks(x)
        ax.set_xticklabels(available_sizes)
        ax.set_xlabel("Training Size")
        ax.set_ylabel("Score Difference from Baseline")
        #ax.set_title(f"{lang_pair.upper()} – Δ from Baseline ({group_name})")
        ax.legend()
        ax.grid(axis='y', linestyle='--', alpha=0.6)

        plt.tight_layout()
        fname = f"{lang_pair}_{group_name.replace(' ', '_')}_delta.pdf"
        fig.savefig(os.path.join("plots", fname), format="pdf", dpi=300)
        plt.close(fig)

print("✅ Grouped delta plots saved in 'plots/' folder")
# Out:
# ✅ Grouped delta plots saved in 'plots/' folder
